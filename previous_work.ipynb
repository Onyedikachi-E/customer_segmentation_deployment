# %% [markdown]
# # Module Assignment 3 Project for Course BAN6800 (Business Analytics Capstone)
#
# - **Task 0** : Business Analytics Project-Ready Dataset

# %% [markdown]
# ### <u>1.0 Intro</u>
# This assignment is about getting ready the dataset that will be used in the Customer Segmentation project for Cognitive Software Solutions. The company has three branches which produces several products. All the products of the company are grouped into five categories which are (Saas, Cloud Services, Security, Artificial Intelligence and Development Tools). Each of these categories stores data on a seperate server. A total of these different reports is expected to be 100,000 records.

# %%
# Import the neccessary libraries

import pandas as pd, warnings
from glob import glob
from sklearn.preprocessing import StandardScaler, LabelEncoder
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# ### <u>1.1 Input Data (Data Integration)</u>
# First, we need to read all the different dataset from all the five categories and carry out a Data Integration process to consolidate to one dataset.

# %%
# Read the directory and fetch all the file names of the category reports using the glob() function to form a list
category_files = glob(pathname="subsidiary_reports/Cognitive*")
print(category_files)
# Out:
# ['subsidiary_reports/Cognitive_Development_Tools_Report.csv', 'subsidiary_reports/Cognitive_Saas_Report.csv', 'subsidiary_reports/Cognitive_Security_Report.csv', 'subsidiary_reports/Cognitive_Artificial_Intelligence_Report.csv', 'subsidiary_reports/Cognitive_Cloud_Services_Report.csv']

# %%
# Import all the category files and merged them into one file using the concat() function 
dataset = pd.concat((pd.read_csv(filepath_or_buffer=file) for file in category_files), ignore_index=True)

# %%
# Confirm if Dataframe has been fully loaded
dataset.head(n=5)
# Out:
#    Customer_ID  Order_ID Subscription_Date  Product_ID Product_Name  \
# 0       2454.0       1.0        03/07/2023          19   ScriptEase
# 1       2167.0       5.0        20/09/2022          18      DevSync
# 2       2063.0       6.0        26/10/2023          19   ScriptEase
# 3       4211.0      22.0        22/02/2022          19   ScriptEase
# 4       1636.0      24.0        03/11/2022          19   ScriptEase
#
#             Category Subscription_Type Usage_Frequency  Revenue_Per_Customer  \
# 0  Development Tools             Basic         Monthly                2097.0
# 1  Development Tools        Enterprise          Weekly                 324.0
# 2  Development Tools        Enterprise           Daily                1701.0
# 3  Development Tools        Enterprise           Daily                3649.0
# 4  Development Tools        Enterprise         Monthly                2047.0
#
#   Payment_Plan  Discount_Applied  Support_Tickets  Feature_Adoption  \
# 0       Annual                24               19                36
# 1       Annual                18               33                84
# 2     Lifetime                29               28                37
# 3     Lifetime                17               27                90
# 4       Annual                25                5                23
#
#    Last_Login  Churn_Status  Customer_Tenure  Customer_Satisfaction  \
# 0  10/12/2023             0                9                      3
# 1  08/05/2023             0                5                      5
# 2  26/10/2023             0                8                      2
# 3  23/06/2023             0                8                      2
# 4  12/08/2023             0                9                      5
#
#   Marketing_Channel  Contract_Renewal  Num_Logins_Last_Month
# 0          Referral                 0                     25
# 1          Referral                 0                     25
# 2          Referral                 0                      7
# 3            Direct                 1                     17
# 4     Advertisement                 0                     14

# %%
# Confirm the number of rows and colums to validate the number of expected records
dataset.shape
# Out:
# (100000, 20)

# %% [markdown]
# With the shape of the dataset being (100000, 20) has confirmed that all the datasets were integrated and has loaded successfully !

# %% [markdown]
# ### <u>2.0 Understanding the dataset</u>
# Next, we start by preparing the dataset for analysis by doing data cleansing and checking out for inconsistencies.

# %%
# Checking out the properties of the dataset
print(dataset.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer_ID            99993 non-null   float64
#  1   Order_ID               99999 non-null   float64
#  2   Subscription_Date      100000 non-null  object
#  3   Product_ID             100000 non-null  int64
#  4   Product_Name           100000 non-null  object
#  5   Category               100000 non-null  object
#  6   Subscription_Type      99998 non-null   object
#  7   Usage_Frequency        100000 non-null  object
#  8   Revenue_Per_Customer   99999 non-null   float64
#  9   Payment_Plan           99995 non-null   object
#  10  Discount_Applied       100000 non-null  int64
#  11  Support_Tickets        100000 non-null  int64
#  12  Feature_Adoption       100000 non-null  int64
#  13  Last_Login             100000 non-null  object
#  14  Churn_Status           100000 non-null  int64
#  15  Customer_Tenure        100000 non-null  int64
#  16  Customer_Satisfaction  100000 non-null  int64
#  17  Marketing_Channel      99999 non-null   object
#  18  Contract_Renewal       100000 non-null  int64
#  19  Num_Logins_Last_Month  100000 non-null  int64
# dtypes: float64(3), int64(9), object(8)
# memory usage: 15.3+ MB
# None

# %%
dataset.describe()
# Out:
#         Customer_ID       Order_ID     Product_ID  Revenue_Per_Customer  \
# count  99993.000000   99999.000000  100000.000000          99999.000000
# mean    2498.455872   50000.171182      10.472070           2527.351314
# std     1442.375827   28868.030051       5.763226           1425.947481
# min        1.000000       1.000000       1.000000             50.000000
# 25%     1249.000000   25000.500000       5.000000           1292.000000
# 50%     2500.000000   49999.000000      10.000000           2525.000000
# 75%     3746.000000   75000.500000      15.000000           3760.500000
# max     5000.000000  100000.000000      20.000000           4999.000000
#
#        Discount_Applied  Support_Tickets  Feature_Adoption   Churn_Status  \
# count      100000.00000     100000.00000     100000.000000  100000.000000
# mean           14.52636         24.47180         59.448800       0.150050
# std             8.66513         14.45266         23.056294       0.357122
# min             0.00000          0.00000         20.000000       0.000000
# 25%             7.00000         12.00000         39.000000       0.000000
# 50%            15.00000         24.00000         59.000000       0.000000
# 75%            22.00000         37.00000         79.000000       0.000000
# max            29.00000         49.00000         99.000000       1.000000
#
#        Customer_Tenure  Customer_Satisfaction  Contract_Renewal  \
# count    100000.000000          100000.000000     100000.000000
# mean          4.998220               3.005540          0.299670
# std           2.584694               1.413177          0.458116
# min           1.000000               1.000000          0.000000
# 25%           3.000000               2.000000          0.000000
# 50%           5.000000               3.000000          0.000000
# 75%           7.000000               4.000000          1.000000
# max           9.000000               5.000000          1.000000
#
#        Num_Logins_Last_Month
# count          100000.000000
# mean               14.508260
# std                 8.654375
# min                 0.000000
# 25%                 7.000000
# 50%                15.000000
# 75%                22.000000
# max                29.000000

# %%
# Describing the dataset using object view
dataset.describe(include=["object"])
# Out:
#        Subscription_Date Product_Name Category Subscription_Type  \
# count             100000       100000   100000             99998
# unique              2738           20        5                 4
# top           2025-01-31   SecureAuth     SaaS               Pro
# freq                 104         5099    20120             25189
#
#        Usage_Frequency Payment_Plan  Last_Login Marketing_Channel
# count           100000        99995      100000             99999
# unique               3            4         426                 5
# top             Weekly      Monthly  31/07/2023      Social Media
# freq             33715        33362         277             20140

# %%
# Checking if there is a nmissing values in the dataset
print(dataset.isnull().values.any())
# Out:
# True

# %% [markdown]
# The checking of the missing value is True, which means there exist missing values in any of the colum

# %%
# Summary of all the columns and the number of missing values for each column
print(dataset.isnull().sum())
# Out:
# Customer_ID              7
# Order_ID                 1
# Subscription_Date        0
# Product_ID               0
# Product_Name             0
# Category                 0
# Subscription_Type        2
# Usage_Frequency          0
# Revenue_Per_Customer     1
# Payment_Plan             5
# Discount_Applied         0
# Support_Tickets          0
# Feature_Adoption         0
# Last_Login               0
# Churn_Status             0
# Customer_Tenure          0
# Customer_Satisfaction    0
# Marketing_Channel        1
# Contract_Renewal         0
# Num_Logins_Last_Month    0
# dtype: int64

# %% [markdown]
# ### 3.0 Data Cleansing begins at this point

# %% [markdown]
# ### a. Handling Missing value
# There are missing values in some of the data columns including the Customer ID column. Next we need to handle the missing data.
# 1. Remove the missing row in the Customer ID column and Order ID as there is no way to resolve which customer or Order has the records.
# 2. Use imputation method of mean, median and mode of each column to fill the other missing value on other columns.

# %%
# Drop the records that has the missing value for Customers and Orders.
dataset = dataset.dropna(subset=["Customer_ID", "Order_ID"])

# %%
# Handle missing value using mean, median and mode imputation for numerical and categorical data
dataset["Subscription_Type"] = dataset["Subscription_Type"].fillna(dataset["Subscription_Type"].mode()[0])
dataset["Revenue_Per_Customer"] = dataset["Revenue_Per_Customer"].fillna(round(dataset["Revenue_Per_Customer"].mean(), 1))
dataset["Payment_Plan"] = dataset["Payment_Plan"].fillna(dataset["Payment_Plan"].mode()[0])
dataset["Marketing_Channel"] = dataset["Marketing_Channel"].fillna(dataset["Marketing_Channel"].mode()[0])

# %%
# Checking if there is a nmissing values in the dataset
print(dataset.isnull().values.any())
# Out:
# False

# %% [markdown]
# ### b. Handling Inconsistent Data
# There is always inconsistencies with different date format. So we will enforce validations to be sure every date colum has same format.
# 1. Next step is to check out the two date columns and enforce validation

# %%
# We will try and format all the data using mixed attribute to dandle each format seperately
dataset['Subscription_Date'] = pd.to_datetime(dataset['Subscription_Date'], format='mixed').dt.strftime('%Y-%m-%d')


dataset['Last_Login'] = pd.to_datetime(dataset['Last_Login'], format='mixed').dt.strftime('%Y-%m-%d')

# %% [markdown]
# ### c. Removing of Duplicates
# Next, we will we will validate the entire dataset for duplicate. We will use the 'drop_duplicates()' to carry out this process.

# %%
# Remove duplicate records
dataset.drop_duplicates(inplace=True)

# %% [markdown]
# ### d. Data Sorting
# Next, we will sort the dataset using Subscription Date. This is make the dataset easily accesible to find information for any record using the customer Subscription date.

# %%
# Sort the dataset using customer date of Subscription
dataset.sort_values(by="Subscription_Date", ascending=True, axis=0, inplace=True)

# %%
# Confirm the first 20 records
dataset.head(n=20)
# Out:
#        Customer_ID  Order_ID Subscription_Date  Product_ID    Product_Name  \
# 15652       2522.0   79247.0        2022-01-01          20      APIConnect
# 23907       1162.0   20774.0        2022-01-01           4       PulseDesk
# 58459       4929.0   92139.0        2022-01-01           5  SentinelShield
# 17587         62.0   88747.0        2022-01-01          17      CodeFusion
# 42608       1969.0   12931.0        2022-01-01           6      FortiGateX
# 43153        488.0   15595.0        2022-01-01           6      FortiGateX
# 48207        128.0   41041.0        2022-01-01           8      SecureAuth
# 28413       4538.0   42836.0        2022-01-01           4       PulseDesk
# 40031       3544.0     437.0        2022-01-01           6      FortiGateX
# 36334       3690.0   82206.0        2022-01-01           2      TaskGenius
# 19385       4795.0   97796.0        2022-01-01          19      ScriptEase
# 5938        3891.0   30060.0        2022-01-01          17      CodeFusion
# 47777       4643.0   38862.0        2022-01-01           5  SentinelShield
# 23398       1446.0   18200.0        2022-01-01           2      TaskGenius
# 74503       2494.0   72221.0        2022-01-01          10     LinguoSense
# 71930        414.0   59508.0        2022-01-01          12       DeepMindX
# 63251        192.0   16427.0        2022-01-01          12       DeepMindX
# 6400        4817.0   32314.0        2022-01-01          18         DevSync
# 6150        2084.0   31016.0        2022-01-01          19      ScriptEase
# 16058        757.0   81185.0        2022-01-01          18         DevSync
#
#                       Category Subscription_Type Usage_Frequency  \
# 15652        Development Tools        Enterprise         Monthly
# 23907                     SaaS              Free           Daily
# 58459                 Security             Basic         Monthly
# 17587        Development Tools             Basic           Daily
# 42608                 Security        Enterprise         Monthly
# 43153                 Security              Free          Weekly
# 48207                 Security              Free         Monthly
# 28413                     SaaS               Pro          Weekly
# 40031                 Security             Basic           Daily
# 36334                     SaaS        Enterprise           Daily
# 19385        Development Tools             Basic           Daily
# 5938         Development Tools        Enterprise         Monthly
# 47777                 Security        Enterprise          Weekly
# 23398                     SaaS               Pro          Weekly
# 74503  Artificial Intelligence               Pro           Daily
# 71930  Artificial Intelligence             Basic          Weekly
# 63251  Artificial Intelligence               Pro         Monthly
# 6400         Development Tools               Pro          Weekly
# 6150         Development Tools               Pro          Weekly
# 16058        Development Tools              Free          Weekly
#
#        Revenue_Per_Customer Payment_Plan  Discount_Applied  Support_Tickets  \
# 15652                3981.0     Lifetime                24                8
# 23907                2623.0      Monthly                22               49
# 58459                4776.0       Annual                24               47
# 17587                1182.0       Annual                 4               47
# 42608                4618.0       Annual                 6                3
# 43153                1616.0      Monthly                14               49
# 48207                3446.0     Lifetime                14               31
# 28413                1470.0      Monthly                 4               15
# 40031                3679.0      Monthly                12               26
# 36334                3122.0      Monthly                21               49
# 19385                2978.0      Monthly                 4               32
# 5938                 4418.0      Monthly                18               27
# 47777                1309.0       Annual                 1               45
# 23398                4723.0     Lifetime                16               12
# 74503                1700.0       Annual                17               19
# 71930                3905.0     Lifetime                23               45
# 63251                3831.0       Annual                 2               15
# 6400                 2259.0       Annual                14                0
# 6150                 4599.0      Monthly                 1               35
# 16058                4018.0      Monthly                17               22
#
#        Feature_Adoption  Last_Login  Churn_Status  Customer_Tenure  \
# 15652                99  2023-06-05             0                5
# 23907                72  2023-09-17             1                4
# 58459                44  2023-07-20             0                2
# 17587                20  2023-07-31             0                6
# 42608                59  2023-02-20             0                4
# 43153                82  2023-01-01             0                5
# 48207                64  2023-11-15             0                7
# 28413                68  2023-07-21             1                8
# 40031                68  2023-01-19             0                1
# 36334                69  2023-09-13             0                1
# 19385                96  2023-12-27             0                1
# 5938                 87  2023-01-01             0                8
# 47777                75  2023-04-08             0                6
# 23398                79  2023-04-16             1                6
# 74503                68  2023-07-05             0                6
# 71930                79  2023-08-04             1                4
# 63251                20  2023-03-27             0                8
# 6400                 68  2023-09-22             1                1
# 6150                 94  2023-04-14             0                1
# 16058                36  2023-08-05             0                6
#
#        Customer_Satisfaction Marketing_Channel  Contract_Renewal  \
# 15652                      3             Email                 1
# 23907                      1      Social Media                 0
# 58459                      3      Social Media                 0
# 17587                      1      Social Media                 1
# 42608                      4          Referral                 0
# 43153                      4          Referral                 0
# 48207                      4             Email                 1
# 28413                      5      Social Media                 0
# 40031                      1     Advertisement                 1
# 36334                      3      Social Media                 1
# 19385                      4          Referral                 1
# 5938                       1          Referral                 0
# 47777                      3      Social Media                 0
# 23398                      2      Social Media                 1
# 74503                      1            Direct                 1
# 71930                      3            Direct                 0
# 63251                      5             Email                 0
# 6400                       2            Direct                 1
# 6150                       4          Referral                 0
# 16058                      1             Email                 0
#
#        Num_Logins_Last_Month
# 15652                     29
# 23907                      5
# 58459                     20
# 17587                      7
# 42608                     15
# 43153                     17
# 48207                     25
# 28413                     27
# 40031                      2
# 36334                      0
# 19385                      3
# 5938                      25
# 47777                      0
# 23398                     12
# 74503                     25
# 71930                      1
# 63251                     17
# 6400                      25
# 6150                      26
# 16058                     25

# %%
# Check the count of all columns
dataset.count()
# Out:
# Customer_ID              99981
# Order_ID                 99981
# Subscription_Date        99981
# Product_ID               99981
# Product_Name             99981
# Category                 99981
# Subscription_Type        99981
# Usage_Frequency          99981
# Revenue_Per_Customer     99981
# Payment_Plan             99981
# Discount_Applied         99981
# Support_Tickets          99981
# Feature_Adoption         99981
# Last_Login               99981
# Churn_Status             99981
# Customer_Tenure          99981
# Customer_Satisfaction    99981
# Marketing_Channel        99981
# Contract_Renewal         99981
# Num_Logins_Last_Month    99981
# dtype: int64

# %% [markdown]
# ### <u>4.0 Feature Engineering</u>
# We will now create some new features in our dataset. These features are essential as they will provide more insight about the customers for better understanding.
# - Customer_Lifetime_Value:
# - Engagement_Score:

# %%
# Feature Engineering
dataset['Customer_Lifetime_Value'] = dataset['Revenue_Per_Customer'] * dataset['Customer_Tenure']
dataset['Engagement_Score'] = dataset['Num_Logins_Last_Month'] + dataset['Feature_Adoption']

# %% [markdown]
# ### <u>4.1 Data Transformation</u>
# This step is done to transform all categorical variables to a numerical encoding for ML Model

# %%
# Data Transformation 1

# Define categorical columns
categorical_cols = ['Product_Name', 'Category', 'Subscription_Type', 'Usage_Frequency', 'Payment_Plan', 'Marketing_Channel']

# Initialize the encoder
label_encoder = LabelEncoder()

# Apply encoding to each column separately
for col in categorical_cols:
    dataset[col] = label_encoder.fit_transform(dataset[col])

# %% [markdown]
# ### <u>Data Export of the cleaned dataset</u>
# Lastly, We have concluded the dataset preparation as required. We will now export the dataset.
# The dataset is fully ready for analysis and ML modeling

# %%
dataset.to_csv(path_or_buf="cognitive_cleaned_dataset.csv", index=False)
